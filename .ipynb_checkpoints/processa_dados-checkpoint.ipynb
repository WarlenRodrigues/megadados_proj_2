# %% [markdown]
# # Projeto MegaDados
#
# **Alunos:**
#
# + Rafael Almada
# + Warlen Cesar Rodrigues
#
# **Professor:** Fábio Ayres

# %%
import pyspark
from math import log10

# %%
sc = pyspark.SparkContext(appName='Projeto e-sports')

# %%
sc
# Out:
# <SparkContext master=local[*] appName=Projeto e-sports>

# %%
rdd = sc.sequenceFile('part-00000')
rdd
# Out:
# MapPartitionsRDD[2] at mapPartitions at SerDeUtil.scala:244

# %%
# result = rdd.take(10)
# result[0]

# %% [markdown]
# ### Montando RDD para Valorant

# %%
#Pegar os documentos que possuem a palavra Valorant
def getValorantWord(item):
    if 'Valorant' in item[1]:
        return item
    
rdd_valorant = rdd.filter(getValorantWord)
rdd_valorant.count()
# Out:
# 996

# %% [markdown]
# ### Montando RDD para Counter Strike

# %%
#Pegar os documentos que possuem a palavra Counter Strike
def getCStWord(item):
    if 'Counter Strike' in item[1]:
        return item
    
rdd_csgo = rdd.filter(getCStWord)
rdd_csgo.count()
# Out:
# 1207

# %% [markdown]
# ### Operacionalização para Intersecção entre Valorant e Counter Strike

# %%
#Pegar somente os documentos que possuem as duas palavras    
rdd_valorant_csgo = rdd_valorant.intersection(rdd_csgo)
rdd_valorant_csgo.count()
# Out:
# 487

# %% [markdown]
# #### Operacionalizando frequência de palavras (1 doc = 1 contagem)

# %%
def conta_palavras(item):
    url, conteudo = item
    palavras = conteudo.strip().split()
    return [(palavra, 1) for palavra in set(palavras)]

def junta_contagens(nova_contagem, contagem_atual):
    return nova_contagem + contagem_atual

rdd_valorant_csgo_doc_freq = rdd_valorant_csgo.flatMap(conta_palavras).reduceByKey(junta_contagens)

# %%
#Listando tuplas (palavra, qtde. de Docs) para intersecção de Valorant e CSGO
#Neste cenário, o valor máximo do value é a quantidade retornada por rdd_valorant_csgo.count()
result = rdd_valorant_csgo_doc_freq.collect() 
sorted(result, key=lambda x : -x[1])
# Out:
# [('de', 487),
#  ('e', 486),
#  ('da', 484),
#  ('do', 484),
#  ('a', 483),
#  ('para', 481),
#  ('o', 478),
#  ('com', 476),
#  ('Flamengo', 475),
#  ('em', 473),
#  ('é', 464),
#  ('que', 464),
#  ('por', 462),
#  ('-', 462),
#  ('São', 456),
#  ('no', 452),
#  ('A', 452),
#  ('mais', 448),
#  ('O', 446),
#  ('na', 446),
#  ('dos', 444),
#  ('os', 442),
#  ('Paulo', 442),
#  ('das', 431),
#  ('Vasco', 430),
#  ('Brasil', 424),
#  ('ao', 424),
#  ('seu', 416),
#  ('Botafogo', 406),
#  ('não', 405),
#  ('ou', 403),
#  ('uma', 401),
#  ('Fluminense', 400),
#  ('Santos', 397),
#  ('à', 395),
#  ('como', 387),
#  ('as', 384),
#  ('um', 383),
#  ('Palmeiras', 377),
#  ('Mais', 372),
#  ('Futebol', 372),
#  ('1', 370),
#  ('Cruzeiro', 366),
#  ('Corinthians', 366),
#  ('2020', 360),
#  ('Os', 359),
#  ('se', 355),
#  ('tem', 354),
#  ('contra', 354),
#  ('Grêmio', 353),
#  ('Por', 349),
#  ('Bahia', 348),
#  ('Todos', 345),
#  ('Internacional', 343),
#  ('Copa', 340),
#  ('sobre', 338),
#  ('Mundo', 337),
#  ('Política', 336),
#  ('Grande', 334),
#  ('conteúdo', 333),
#  ('direitos', 331),
#  ('Goiás', 325),
#  ('Saúde', 325),
#  ('Notícias', 325),
#  ('Casa', 324),
#  ('Ceará', 323),
#  ('dia', 323),
#  ('fazer', 319),
#  ('TV', 319),
#  ('No', 319),
#  ('Esporte', 318),
#  ('Fortaleza', 318),
#  ('Clube', 317),
#  ('Não', 316),
#  ('Série', 315),
#  ('Liga', 313),
#  ('12', 313),
#  ('Bom', 309),
#  ('Jogos', 308),
#  ('Brasileirão', 308),
#  ('foi', 306),
#  ('casa', 304),
#  ('Novo', 304),
#  ('Bola', 302),
#  ('jogos', 302),
#  ('Como', 301),
#  ('Na', 299),
#  ('mundo', 299),
#  ('melhor', 298),
#  ('©', 297),
#  ('Libertadores', 297),
#  ('B', 297),
#  ('Você', 296),
#  ('Fora', 295),
#  ('Sport', 292),
#  ('produtos', 290),
#  ('Sem', 290),
#  ('sua', 289),
#  ('Últimas', 288),
#  ('Basquete', 287),
#  ('está', 287),
#  ('história', 286),
#  ('Chapecoense', 285),
#  ('Segurança', 284),
#  ('Coritiba', 283),
#  ('ser', 283),
#  ('precisa', 281),
#  ('dentro', 281),
#  ('Tênis', 279),
#  ('todo', 279),
#  ('hoje', 279),
#  ('Nossa', 278),
#  ('Mercado', 277),
#  ('Vôlei', 276),
#  ('Atlético-GO', 275),
#  ('pela', 275),
#  ('Times', 275),
#  ('pelo', 275),
#  ('Digital', 275),
#  ('Direitos', 274),
#  ('Rede', 273),
#  ('tenha', 272),
#  ('Ao', 272),
#  ('La', 272),
#  ('Loja', 271),
#  ('mulher', 271),
#  ('notícias', 271),
#  ('eu', 270),
#  ('horas', 269),
#  ('Economia', 268),
#  ('Eu', 267),
#  ('Fazenda', 267),
#  ('As', 267),
#  ('pra', 266),
#  ('Educação', 266),
#  ('Redes', 265),
#  ('Pessoais', 265),
#  ('mas', 265),
#  ('História', 264),
#  ('Bragantino', 263),
#  ('ver', 263),
#  ('Vídeos', 263),
#  ('sem', 263),
#  ('Alta', 263),
#  ('atendimento', 262),
#  ('Minha', 261),
#  ('Produtos', 260),
#  ('WhatsApp', 260),
#  ('Tabela', 259),
#  ('UOL', 259),
#  ('Famosos', 259),
#  ('Mídia', 259),
#  ('Meu', 258),
#  ('Dicas', 258),
#  ('Música', 258),
#  ('Folha', 257),
#  ('tão', 256),
#  ('Novos', 256),
#  ('Bolsa', 256),
#  ('vídeo', 256),
#  ('Especiais', 255),
#  ('Vida', 254),
#  ('Campeões', 253),
#  ('League', 253),
#  ('seria', 253),
#  ('Reforma', 253),
#  ('Guia', 252),
#  ('Isso', 252),
#  ('até', 252),
#  ('Assine', 252),
#  ('Red', 252),
#  ('Sociais', 252),
#  ('programa', 252),
#  ('Filmes', 252),
#  ('Coronavírus', 251),
#  ('MMA', 251),
#  ('ponto', 250),
#  ('Papo', 250),
#  ('vivo', 250),
#  ('cabeça', 250),
#  ('Blogs', 250),
#  ('Carros', 249),
#  ('Empresas', 249),
#  ('mão', 249),
#  ('Moda', 248),
#  ('Black', 248),
#  ('pode', 248),
#  ('veja', 248),
#  ('Coração', 247),
#  ('demais', 247),
#  ('P', 247),
#  ('favor', 247),
#  ('Café', 247),
#  ('também', 247),
#  ('Baixo', 247),
#  ('Renda', 246),
#  ('Previdência', 246),
#  ('Dúvidas', 246),
#  ('Viagem', 246),
#  ('Fórmula', 245),
#  ('Mulheres', 245),
#  ('Ciência', 245),
#  ('Entrevista', 245),
#  ('Sena', 244),
#  ('estilo', 244),
#  ('carros', 244),
#  ('Athletico', 244),
#  ('Eliminatórias', 244),
#  ('entre', 244),
#  ('Posse', 244),
#  ('Essa', 243),
#  ('Primeira', 243),
#  ('acesso', 243),
#  ('Conteúdo', 243),
#  ('Negócios', 243),
#  ('Cozinha', 242),
#  ('após', 242),
#  ('Outras', 242),
#  ('Premier', 242),
#  ('funciona', 242),
#  ('vídeos', 242),
#  ('Estrada', 242),
#  ('Bull', 242),
#  ('família', 241),
#  ('Juca', 241),
#  ('Cursos', 241),
#  ('Final', 240),
#  ('Opinião', 240),
#  ('Alimentação', 240),
#  ('Marketing', 240),
#  ('Receita', 240),
#  ('Livros', 240),
#  ('Assistência', 239),
#  ('ruim', 239),
#  ('são', 239),
#  ('prática', 238),
#  ('Mães', 238),
#  ('Empregos', 238),
#  ('Carro', 238),
#  ('Perfil', 238),
#  ('Dinheiro', 238),
#  ('Beleza', 238),
#  ('Força', 238),
#  ('Técnica', 238),
#  ('Bate-papo', 237),
#  ('Steve', 237),
#  ('conhecer', 237),
#  ('campeonatos', 237),
#  ('ideia', 237),
#  ('Dólar', 237),
#  ('Nações', 237),
#  ('Ficha', 236),
#  ('trás', 236),
#  ('especiais', 236),
#  ('Motos', 236),
#  ('feliz', 236),
#  ('Me', 236),
#  ('Loterias', 236),
#  ('de...', 236),
#  ('Retrato', 236),
#  ('Valores', 236),
#  ('Play', 236),
#  ('finanças', 235),
#  ('0800', 235),
#  ('Movimento', 235),
#  ('Televisão', 235),
#  ('Retratos', 235),
#  ('Violência', 235),
#  ('Podcast', 234),
#  ('Reportagens', 234),
#  ('Fipe', 234),
#  ('Olimpíadas', 233),
#  ('703', 233),
#  ('loterias', 233),
#  ('colunas', 233),
#  ('3000', 233),
#  ('Novelas', 233),
#  ('Host', 233),
#  ('NBA', 233),
#  ('Explica', 233),
#  ('Lotofácil', 233),
#  ('Newsletter', 233),
#  ('Universa', 233),
#  ('Feito', 232),
#  ('Cotidiano', 232),
#  ('Viva', 232),
#  ('Maratona', 232),
#  ('Colunistas', 232),
#  ('Quase', 231),
#  ('tecnologia', 231),
#  ('shows', 231),
#  ('Horóscopo', 231),
#  ('Séries', 231),
#  ('Fique', 230),
#  ('Sexo', 230),
#  ('Finanças', 230),
#  ('Negras', 230),
#  ('Receitas', 230),
#  ('nos', 230),
#  ('Banca', 229),
#  ('Splash', 229),
#  ('Filhos', 229),
#  ('Segredos', 229),
#  ('filtro', 229),
#  ('Cena', 229),
#  ('Resumo', 229),
#  ('Atletas', 228),
#  ('Mega', 228),
#  ('Viajantes', 228),
#  ('exclusivo', 228),
#  ('Ficção', 228),
#  ('Tapa', 228),
#  ('roupa', 228),
#  ('Sim', 228),
#  ('noticias', 228),
#  ('Negócio', 228),
#  ('Pessoas', 228),
#  ('Mobilidade', 228),
#  ('Euro', 228),
#  ('já', 228),
#  ('Vê', 227),
#  ('Programas', 227),
#  ('Equilíbrio', 227),
#  ('Exclusivo', 227),
#  ('(na', 227),
#  ('Temporadas', 227),
#  ('inspiradoras', 227),
#  ('Avaliação', 227),
#  ('Vidas', 227),
#  ('Podcasts', 227),
#  ('Apocalipse', 227),
#  ('Reality', 227),
#  ('Trás', 226),
#  ('Imposto', 226),
#  ('diria', 226),
#  ('Incríveis', 226),
#  ('não?', 226),
#  ('Topo', 226),
#  ('Quina', 226),
#  ('Segue', 226),
#  ('Dieta', 226),
#  ('poderosa', 226),
#  ('IR', 226),
#  ('agora', 226),
#  ('Especialista', 226),
#  ('Geração', 226),
#  ('Lançamentos', 225),
#  ('Líderes', 225),
#  ('capitais', 225),
#  ('Astronomia', 225),
#  ('Planos', 225),
#  ('Lugares', 225),
#  ('Mirror', 225),
#  ('Longevidade', 225),
#  ('Diversidade', 225),
#  ('nas', 225),
#  ('Eleições', 224),
#  ('se...', 224),
#  ('Achados', 224),
#  ('Festejo', 224),
#  ('estimação', 224),
#  ('chefia', 224),
#  ('Querer', 224),
#  ('Deu', 224),
#  ('Review', 224),
#  ('Haja', 224),
#  ('Newsletters', 224),
#  ('hábitos', 224),
#  ('Atletico-MG', 224),
#  ('Autoestima', 224),
#  ('Carreiras', 224),
#  ('mudam', 224),
#  ('Soluções', 224),
#  ('Malhação', 224),
#  ('Criminal', 224),
#  ('Start', 223),
#  ('Pensando', 223),
#  ('mereço', 223),
#  ('Causadores', 223),
#  ('Inspira', 223),
#  ('4003-6118', 223),
#  ('Empreendedorismo', 223),
#  ('experimenta', 223),
#  ('inspiram', 223),
#  ('erre', 223),
#  ('Lotomania', 223),
#  ('Stalkeadas', 223),
#  ('Fizeram', 223),
#  ('rota', 223),
#  ('localidades', 223),
#  ('Duelo', 223),
#  ('Relacionamentos', 223),
#  ('Carro,', 223),
#  ('VivaBem', 223),
#  ('Destretando', 223),
#  ('Pausa', 223),
#  ('Investidor', 223),
#  ('Mail', 223),
#  ('Retina', 223),
#  ('Sexoterapia', 223),
#  ('Transforma', 223),
#  ('Trabalhar', 223),
#  ('Cotações', 223),
#  ('Tilt', 223),
#  ('Resolve', 223),
#  ('PitsTOP', 223),
#  ('Iniciativas', 223),
#  ('Plural', 223),
#  ('Ecoa', 223),
#  ('Leia+', 223),
#  ('Poucas', 223),
#  ('TAB', 223),
#  ('moedas', 223),
#  ('Meteoro', 223),
#  ('PUBLICIDADE', 223),
#  ('farmácias', 223),
#  ('MOV', 223),
#  ('MOV.doc', 223),
#  ('Fofuras', 223),
#  ('Clero', 223),
#  ('Muleke', 223),
#  ('Automotivos', 223),
#  ('Confere', 223),
#  ('Diferença', 222),
#  ('PagBank', 222),
#  ('Med', 222),
#  ('Sul-Americanas', 222),
#  ('ads', 222),
#  ('Plantados', 222),
#  ('matadoras', 222),
#  ('Talks', 222),
#  ('Tim-tim', 222),
#  ('OtaLab', 222),
#  ('WI-FI', 222),
#  ('Moodboard', 222),
#  ('Entrevistão', 222),
#  ('Instachef', 222),
#  ('sac', 222),
#  ('Chiquititas', 222),
#  ('Memelândia', 222),
#  ('Golpe!', 222),
#  ('Tec', 222),
#  ('Entornos', 222),
#  ('apê', 222),
#  ('Download', 222),
#  ('Comparativo', 222),
#  ('Marinando', 222),
#  ('Séloko', 222),
#  ('Futparódias', 222),
#  ('MED', 222),
#  ('Microespaços', 222),
#  ('quarentena)', 222),
#  ('Apps', 222),
#  ('científica?', 222),
#  ('Celebs', 222),
#  ('#ficadica', 222),
#  ('Tio!', 222),
#  ('Gastronobásico', 222),
#  ('Economia+', 222),
#  ('ilimitado', 222),
#  ('Fala,', 222),
#  ('anos', 218),
#  ('reservados', 217),
#  ('diz', 215),
#  ('Com', 212),
#  ('R$', 212),
#  ('Para', 211),
#  ('Em', 210),
#  ('Rio', 209),
#  ('00:00', 206),
#  ('privacidade', 206),
#  ('às', 204),
#  ('+', 203),
#  ('aos', 199),
#  ('1996', 197),
#  ('conteúdo.', 197),
#  ('ter', 196),
#  ('Home', 194),
#  ('2', 193),
#  ('X', 193),
#  ('lidas', 189),
#  ('ainda', 187),
#  ('novo', 186),
#  ('será', 184),
#  ('vai', 182),
#  ('você', 179),
#  ('nesta', 174),
#  ('&', 172),
#  ('muito', 172),
#  ('seus', 171),
#  ('Pagseguro', 170),
#  ('BATE-PAPO', 170),
#  ('3', 168),
#  ('10', 167),
#  ('mesmo', 166),
#  ('todos', 162),
#  ('É', 159),
#  ('5', 158),
#  ('faz', 156),
#  ('Janeiro', 155),
#  ('só', 153),
#  ('Veja', 151),
#  ('ano', 150),
#  ('Contato', 149),
#  ('0', 149),
#  ('primeiro', 148),
#  ('deste', 148),
#  ('estão', 147),
#  ('foram', 146),
#  ('final', 146),
#  ('7', 145),
#  ('Nova', 145),
#  ('vez', 143),
#  ('bem', 143),
#  ('–', 142),
#  ('primeira', 140),
#  ('Santa', 140),
#  ('Cultura', 140),
#  ('Nacional', 139),
#  ('VER', 139),
#  ('jogo', 139),
#  ('três', 138),
#  ('suas', 138),
#  ('segundo', 138),
#  ('quem', 138),
#  ('4', 137),
#  ('durante', 136),
#  ('dois', 136),
#  ('nova', 136),
#  ('onde', 135),
#  ('quando', 135),
#  ('antes', 134),
#  ('mil', 134),
#  ('deve', 133),
#  ('conta', 132),
#  ('maior', 132),
#  ('Canais', 131),
#  ('tudo', 131),
#  ('José', 131),
#  ('João', 131),
#  ('time', 131),
#  ('duas', 130),
#  ('futebol', 130),
#  ('meio', 129),
#  ('América', 129),
#  ('Imagem:', 129),
#  ('SP', 128),
#  ('há', 128),
#  ('E', 127),
#  ('Design', 126),
#  ('x', 125),
#  ('grande', 125),
#  ('site', 124),
#  ('Sul', 123),
#  ('15', 123),
#  ('busca', 122),
#  ('dias', 122),
#  ('Carlos', 121),
#  ('Twitter', 121),
#  ('semana', 121),
#  ('De', 121),
#  ('partir', 120),
#  ('Europa', 120),
#  ('equipe', 120),
#  ('|', 120),
#  ('Vila', 120),
#  ('Facebook', 119),
#  ('Campeonato', 119),
#  ('30', 119),
#  ('Real', 119),
#  ('aqui', 118),
#  ('outros', 118),
#  ('tempo', 117),
#  ('volta', 117),
#  ('Band', 115),
#  ('Arte', 114),
#  ('parte', 114),
#  ('6', 114),
#  ('Parceiros', 113),
#  ('vida', 113),
#  ('Quem', 113),
#  ('vence', 113),
#  ('isso', 113),
#  ('era', 113),
#  ('Norte', 113),
#  ('ele', 112),
#  ('Cruz', 112),
#  ('Além', 111),
#  ('desde', 111),
#  ('disse', 111),
#  ('20', 111),
#  ('Inovação', 110),
#  ('este', 110),
#  ('Sociedade', 110),
#  ('Paulista', 109),
#  ('caso', 109),
#  ('Vitória', 109),
#  ('me', 109),
#  ('cada', 108),
#  ('Curiosidades', 108),
#  ('neste', 108),
#  ('governo', 107),
#  ('11', 107),
#  ('Comportamento', 107),
#  ('todas', 107),
#  ('pelos', 107),
#  ('menos', 106),
#  ('brasileiro', 106),
#  ('Entrevistas', 106),
#  ('Ver', 106),
#  ('Um', 105),
#  ('9', 105),
#  ('forma', 104),
#  ('depois', 104),
#  ('dá', 103),
#  ('Edições', 103),
#  ('Centro', 103),
#  ('online', 103),
#  ('apenas', 103),
#  ('Caras', 103),
#  ('desta', 103),
#  ('Assista', 102),
#  ('Ponte', 102),
#  ('Após', 102),
#  ('Se', 102),
#  ('nossa', 102),
#  ('PagSeguro', 102),
#  ('pessoas', 101),
#  ('GRÁTIS', 101),
#  ('milhões', 101),
#  ('DE', 101),
#  ('fim', 101),
#  ('Presidente', 100),
#  ('teve', 100),
#  ('RedeTV!', 100),
#  ('Uma', 100),
#  ('podem', 99),
#  ('anos,', 99),
#  ('Estados', 99),
#  ('início', 99),
#  ('outubro', 99),
#  ('(11)', 99),
#  ('Reviews', 98),
#  ('acordo', 98),
#  ('Minas', 98),
#  ('Jorge', 97),
#  ('Tendência', 97),
#  ('Paraná', 97),
#  ('têm', 97),
#  ('Porto', 97),
#  ('eSports', 97),
#  ('Luiz', 97),
#  ('vitória', 97),
#  ('8', 97),
#  ('bom', 96),
#  ('Maria', 96),
#  ('04h00', 96),
#  ('Guias', 96),
#  ('Outros', 96),
#  ('sempre', 95),
#  ('porque', 95),
#  ('Do', 95),
#  ('esse', 95),
#  ('fala', 95),
#  ('sendo', 94),
#  ('pandemia', 94),
#  ('Costa', 94),
#  ('além', 94),
#  ('Santo', 94),
#  ('History', 93),
#  ('Brasileiro', 93),
#  ('última', 93),
#  ('meses', 93),
#  ('terá', 92),
#  ('Belo', 92),
#  ('Nordeste', 92),
#  ('mostra', 92),
#  ('Sobre', 92),
#  ('segunda', 92),
#  ('Dia', 92),
#  ('fora', 91),
#  ('Argentina', 91),
#  ('18', 91),
#  ('fez', 91),
#  ('quatro', 91),
#  ('Recife', 91),
#  ('boa', 90),
#  ('Preta', 90),
#  ('Artes', 90),
#  ('direito', 89),
#  ('Cidade', 89),
#  ('sucesso', 89),
#  ('clube', 89),
#  ('Entre', 89),
#  ('redes', 89),
#  ('possível', 89),
#  ('deu', 89),
#  ('Lucas', 89),
#  ('técnico', 88),
#  ('Campo', 88),
#  ('nome', 88),
#  ('outras', 88),
#  ('Mas', 88),
#  ('contato', 88),
#  ('marca', 88),
#  ('quer', 88),
#  ('ela', 87),
#  ('último', 87),
#  ('Esportes', 87),
#  ('Bolsonaro', 87),
#  ('2019', 87),
#  ('Gama', 87),
#  ('cinco', 86),
#  ('Pesquisa', 86),
#  ('Ele', 86),
#  ('trabalho', 86),
#  ('grupo', 86),
#  ('nosso', 86),
#  ('13', 86),
#  ('estava', 86),
#  ('melhores', 86),
#  ('Brasília', 85),
#  ('deixa', 85),
#  ('Oeste', 85),
#  ('anuncia', 85),
#  ('Francisco', 85),
#  ('2018', 85),
#  ('empresa', 85),
#  ('toda', 85),
#  ('essa', 85),
#  ('Serra', 85),
#  ('Geral', 85),
#  ('Boa', 84),
#  ('Gerais', 84),
#  ('Barra', 84),
#  ('21', 84),
#  ('Pedro', 84),
#  ('outro', 83),
#  ('Lei', 83),
#  ('Barcelona', 82),
#  ('fica', 82),
#  ('quase', 82),
#  ('Escola', 82),
#  ('André', 82),
#  ('mulheres', 82),
#  ('seleção', 82),
#  ('lado', 81),
#  ('dar', 81),
#  ('Banco', 81),
#  ('qualquer', 81),
#  ('/', 81),
#  ('Brasileira', 81),
#  ('Atlético-MG', 81),
#  ('alguns', 81),
#  ('DO', 81),
#  ('saber', 81),
#  ('14', 80),
#  ('campo', 80),
#  ('pouco', 80),
#  ('presidente', 80),
#  ('número', 80),
#  ('estar', 80),
#  ('Eduardo', 80),
#  ('Vale', 80),
#  ('jogadores', 80),
#  ('Entretenimento', 80),
#  ('Gabriel', 80),
#  ('Itália', 80),
#  ('temporada', 79),
#  ('Portugal', 79),
#  ('Placar', 79),
#  ('19', 79),
#  ('fase', 79),
#  ('Miguel', 79),
#  ('Seleção', 79),
#  ('Segundo', 78),
#  ('brasileira', 78),
#  ('Santana', 78),
#  ('Bruno', 78),
#  ('hora', 78),
#  ('Rocha', 78),
#  ('temas', 78),
#  ('Três', 78),
#  ('mês', 78),
#  ('partida', 78),
#  ('livros', 77),
#  ('Ribeiro', 77),
#  ('Paulo,', 77),
#  ('Já', 77),
#  ('Leão', 77),
#  ('importante', 77),
#  ('França', 77),
#  ('texto', 77),
#  ('Atlético', 77),
#  ('Catarina', 77),
#  ('feito', 77),
#  ('profissionais', 77),
#  ('gol', 77),
#  ('sido', 76),
#  ('e,', 76),
#  ('relação', 76),
#  ('título', 76),
#  ('vem', 76),
#  ('Blog', 76),
#  ('Português', 76),
#  ('informações', 76),
#  ('dados', 75),
#  ('Carioca', 75),
#  ('24', 75),
#  ('»', 75),
#  ('Mineiro', 75),
#  ('noite', 75),
#  ('lugar', 75),
#  ('Marcelo', 75),
#  ('autorização', 75),
#  ('Central', 74),
#  ('Japão', 74),
#  ('Silva', 74),
#  ('receber', 74),
#  ('que,', 74),
#  ('Campos', 74),
#  ('Alegre', 74),
#  ('Faça', 74),
#  ('Rafael', 74),
#  ('Copyright', 73),
#  ('país', 73),
#  ('isso,', 73),
#  ('Página', 73),
#  ('Volta', 73),
#  ('Química', 73),
#  ('Preto', 73),
#  ('segurança', 72),
#  ('Alves', 72),
#  ('Sul-Americana', 72),
#  ('meu', 72),
#  ('estreia', 72),
#  ('tinha', 72),
#  ('ganha', 72),
#  ('Horizonte', 72),
#  ('16', 72),
#  ('Brasil,', 72),
#  ('Bento', 72),
#  ('Escolar', 72),
#  ('Tecnologia', 72),
#  ('vê', 71),
#  ('artigo', 71),
#  ('novos', 71),
#  ('momento', 71),
#  ('Oliveira', 71),
#  ('Caetano', 71),
#  ('22', 71),
#  ('enquanto', 71),
#  ('Paris', 71),
#  ('domingo', 70),
#  ('deixar', 70),
#  ('Jardim', 70),
#  ('Amazônia', 70),
#  ('edição', 70),
#  ('alta', 70),
#  ('muitas', 70),
#  ('Antônio', 70),
#  ('17', 70),
#  ('próximo', 70),
#  ('assim', 69),
#  ('Enem', 69),
#  ('campanha', 69),
#  ('série', 69),
#  ('qual', 69),
#  ('nossos', 69),
#  ('Fernando', 69),
#  ('principais', 69),
#  ('chega', 69),
#  ('Justiça', 69),
#  ('abre', 69),
#  ('novembro', 69),
#  ('25', 69),
#  ('rodada', 69),
#  ('Luís', 69),
#  ('cidade', 69),
#  ('Família', 69),
#  ('Salvador', 69),
#  ('Lima', 69),
#  ('Neves', 68),
#  ('28', 68),
#  ('Sampaio', 68),
#  ('Jesus', 68),
#  ('Felipe', 68),
#  ('pontos', 68),
#  ('sob', 68),
#  ('Vista', 68),
#  ('bola', 68),
#  ('Governo', 67),
#  ('lista', 67),
#  ('OAB', 67),
#  ('disso,', 67),
#  ('aula', 67),
#  ('sociais', 67),
#  ('área', 67),
#  ('Sua', 67),
#  ('Estado', 66),
#  ('falta', 66),
#  ('Câmara', 66),
#  ('Rua', 66),
#  ('EUA', 66),
#  ('vezes', 66),
#  ('100', 66),
#  ('quarta-feira', 66),
#  ('foto', 66),
#  ('seis', 66),
#  ('Alemanha', 66),
#  ('Caixa', 66),
#  ('Verde', 66),
#  ('Domingos', 66),
#  ('logo', 66),
#  ('vão', 66),
#  ('40', 66),
#  ('Filho', 66),
#  ('UOL,', 66),
#  ('29', 66),
#  ('ficou', 65),
#  ('Rodrigo', 65),
#  ('Água', 65),
#  ('frente', 65),
#  ('gols', 65),
#  ('Parque', 65),
#  ('Renato', 65),
#  ('Avaí', 65),
#  ('Código', 65),
#  ('Isabel', 65),
#  ('Google', 65),
#  ('Artigos', 65),
#  ('23', 65),
#  ('Dois', 65),
#  ('brasileiros', 65),
#  ('Natal', 65),
#  ('derrota', 65),
#  ('casos', 65),
#  ('gente', 65),
#  ('serviços', 65),
#  ('canais', 64),
#  ('Física', 64),
#  ('seja', 64),
#  ('resultados', 64),
#  ('outra', 64),
#  ('Fale', 64),
#  ('Rosa', 64),
#  ('jogador', 64),
#  ('carro', 64),
#  ('preço', 64),
#  ('Baixada', 64),
#  ('Penha', 64),
#  ('Franco', 64),
#  ('Este', 64),
#  ('Outubro', 64),
#  ('2016', 64),
#  ('Branca', 64),
#  ('dinheiro', 64),
#  ('valor', 64),
#  ('público', 64),
#  ('Mundial', 63),
#  ('perde', 63),
#  ('Reis', 63),
#  ('comprar', 63),
#  ('Da', 63),
#  ('União', 63),
#  ('Tem', 63),
#  ('Curitiba', 63),
#  ('Atendimento', 63),
#  ('Andrade', 63),
#  ('Saiba', 63),
#  ('parcial', 63),
#  ('havia', 63),
#  ('Grupo', 63),
#  ('Praia', 63),
#  ('ficar', 62),
#  ('50', 62),
#  ('Madrid', 62),
#  ('Rússia', 62),
#  ('revela', 62),
#  ('27', 62),
#  ('Ainda', 62),
#  ('Campinas', 62),
#  ('perder', 62),
#  ('minha', 62),
#  ('Rica', 62),
#  ('serão', 62),
#  ('Roberto', 62),
#  ('pagamento', 62),
#  ('covid-19', 62),
#  ('Feminino', 62),
#  ('Homem', 61),
#  ('reservados.', 61),
#  ('principal', 61),
#  ('Novas', 61),
#  ('nem', 61),
#  ('2014', 61),
#  ('D', 61),
#  ('Time', 61),
#  ('quanto', 61),
#  ('Cabo', 61),
#  ...]

# %% [markdown]
# #### Fazendo o recorte de palavras muito específicas ou muito comuns

# %%
DOC_COUNT_MIN = 0 # Isso deve mudar de amostra para amostra
DOC_COUNT_MAX = 10 # Isso deve mudar de amostra para amostra (0.7 * rdd.count())

def filtra_doc_freq(item):
    contagem = item[1]
    return (contagem < DOC_COUNT_MAX) & (contagem >= DOC_COUNT_MIN)

rdd_valorant_csgo_freq_filtrado = rdd_valorant_csgo_doc_freq.filter(filtra_doc_freq)

# %%
rdd_valorant_csgo_freq_filtrado.take(10)
# Out:
# [('Bloodline', 1),
#  ('Among', 2),
#  ('Immortals"', 1),
#  ('fechado,', 2),
#  ('"todo', 1),
#  ('"Multiplayer', 1),
#  ('cujos', 5),
#  ('"League', 1),
#  ('exigem', 8),
#  ('personagens', 7)]

# %% [markdown]
# #### Calculo do IDF para as palavras encontradas em documentos que possuem Valorant E Counter Strike

# %%
def idf(item):
    palavra, contagem = item
    return (palavra, log10(N/contagem))

rdd_idf = rdd_valorant_csgo_freq_filtrado.map(idf)
result = rdd_idf.collect()
sorted(result, key=lambda x : x[1])[-100:]
# Out:
# [('equivocado.', 4.557904021057566),
#  ('Carimba?', 4.557904021057566),
#  ('admitisse', 4.557904021057566),
#  ('sacando', 4.557904021057566),
#  ('polpem', 4.557904021057566),
#  ('robo', 4.557904021057566),
#  ('Kk', 4.557904021057566),
#  ('raciocinar', 4.557904021057566),
#  ('balcânica', 4.557904021057566),
#  ('06:55', 4.557904021057566),
#  ('Slams?', 4.557904021057566),
#  ('atp', 4.557904021057566),
#  ('“barro”', 4.557904021057566),
#  ('“isso”.', 4.557904021057566),
#  ('2.0,taí,exatamente', 4.557904021057566),
#  ('Philippoussis', 4.557904021057566),
#  ('(rrsrs),', 4.557904021057566),
#  ('08:44', 4.557904021057566),
#  ('15:36', 4.557904021057566),
#  ('fanaticas,', 4.557904021057566),
#  ('06:51', 4.557904021057566),
#  ('afogou?', 4.557904021057566),
#  ('Chinês,', 4.557904021057566),
#  ('NIMEROS', 4.557904021057566),
#  ('irritou', 4.557904021057566),
#  ('Reveillon,apostem', 4.557904021057566),
#  ('quanto.', 4.557904021057566),
#  ('alguns!', 4.557904021057566),
#  ('impactava', 4.557904021057566),
#  ('Moya', 4.557904021057566),
#  ('6-1', 4.557904021057566),
#  ('tops).', 4.557904021057566),
#  ('homogeneização', 4.557904021057566),
#  ('freguês,', 4.557904021057566),
#  ('neh?', 4.557904021057566),
#  ('NOLE….', 4.557904021057566),
#  ('protegido,', 4.557904021057566),
#  ('CUSTA', 4.557904021057566),
#  ('baloeiro.', 4.557904021057566),
#  ('então…', 4.557904021057566),
#  ('velozes.', 4.557904021057566),
#  ('inumano.', 4.557904021057566),
#  ('intenções,', 4.557904021057566),
#  ('despercebido;', 4.557904021057566),
#  ('viúvos/antis', 4.557904021057566),
#  ('exemplificar', 4.557904021057566),
#  ('08:59', 4.557904021057566),
#  ('superação,', 4.557904021057566),
#  ('Open).', 4.557904021057566),
#  ('deus,', 4.557904021057566),
#  ('imagino', 4.557904021057566),
#  ('Igor?', 4.557904021057566),
#  ('presenciei', 4.557904021057566),
#  ('Enfrentou', 4.557904021057566),
#  ('wue', 4.557904021057566),
#  ('Deeeus!', 4.557904021057566),
#  ('sobra),', 4.557904021057566),
#  ('tenista,', 4.557904021057566),
#  ('agua', 4.557904021057566),
#  ('agiria', 4.557904021057566),
#  ('cachorrões', 4.557904021057566),
#  ('hein?', 4.557904021057566),
#  ('slices,', 4.557904021057566),
#  ('Concordo.', 4.557904021057566),
#  ('kkkkkkkkkkkkkkkkkkkkkkkkkkk', 4.557904021057566),
#  ('nexo', 4.557904021057566),
#  ('temporada,mais', 4.557904021057566),
#  ('detalhar', 4.557904021057566),
#  ('23:03', 4.557904021057566),
#  ('(muito', 4.557904021057566),
#  ('admitir,', 4.557904021057566),
#  ('Djokovic”!!!????', 4.557904021057566),
#  ('nadal,não', 4.557904021057566),
#  ('Dalcim.', 4.557904021057566),
#  ('sofrendo,', 4.557904021057566),
#  ('dura….', 4.557904021057566),
#  ('kkkkkkkkkkkkkkkkkkkkk,', 4.557904021057566),
#  ('quiserem????', 4.557904021057566),
#  ('13:02', 4.557904021057566),
#  ('preferido…', 4.557904021057566),
#  ('hein????', 4.557904021057566),
#  ('aperfeiçoamentos.', 4.557904021057566),
#  ('arraigado', 4.557904021057566),
#  ('Dutra"', 4.557904021057566),
#  ('coletada', 4.557904021057566),
#  ('Dutra?', 4.557904021057566),
#  ('0:35', 4.557904021057566),
#  ('0:09', 4.557904021057566),
#  ('porta",', 4.557904021057566),
#  ('assimilação', 4.557904021057566),
#  ('#corinthians', 4.557904021057566),
#  ('Méndez', 4.557904021057566),
#  ('17:10:', 4.557904021057566),
#  ('17:53:26', 4.557904021057566),
#  ('noite:', 4.557904021057566),
#  ('EDEVE', 4.557904021057566),
#  ('reviravolta', 4.557904021057566),
#  ('rival:', 4.557904021057566),
#  ('10:33:', 4.557904021057566),
#  ('anunciado,', 4.557904021057566)]

# %% [markdown]
# #### Calculo da frequencia e relevância das palavras

# %%
def freq_palavra(item):
    palavra, contagem = item
    return (palavra, log10(1+contagem))

def relevancia(item):
    palavra, freq = item
    freq_calc = freq_palavra(item)
    idf_calc = idf(item)
    relev = freq_calc[1]*idf_calc[1]
    return (palavra, relev)

# %%
freq_filtrado_sort_by_key_rdd = rdd_valorant_csgo_freq_filtrado.sortByKey()
rdd_relevancia_ambas_palavras_mesmo_doc = freq_filtrado_sort_by_key_rdd.map(relevancia)
res = rdd_relevancia_ambas_palavras_mesmo_doc.collect()
sorted(res, key=lambda x : x[1])[-100:]
# Out:
# [('restaurantes', 3.6036615116182413),
#  ('resultados,', 3.6036615116182413),
#  ('retornar', 3.6036615116182413),
#  ('revelar', 3.6036615116182413),
#  ('revelação:', 3.6036615116182413),
#  ('revisão', 3.6036615116182413),
#  ('revés', 3.6036615116182413),
#  ('ritmo', 3.6036615116182413),
#  ('rodas', 3.6036615116182413),
#  ('roubar', 3.6036615116182413),
#  ('salarial', 3.6036615116182413),
#  ('sancionam', 3.6036615116182413),
#  ('santa', 3.6036615116182413),
#  ('segunda,', 3.6036615116182413),
#  ('segunda-feira.', 3.6036615116182413),
#  ('seios', 3.6036615116182413),
#  ('selecione', 3.6036615116182413),
#  ('semelhante', 3.6036615116182413),
#  ('senegal', 3.6036615116182413),
#  ('sertanejo', 3.6036615116182413),
#  ('sicas', 3.6036615116182413),
#  ('sicos', 3.6036615116182413),
#  ('sim,', 3.6036615116182413),
#  ('sintomas', 3.6036615116182413),
#  ('sobre:', 3.6036615116182413),
#  ('sobretudo', 3.6036615116182413),
#  ('sobreviver', 3.6036615116182413),
#  ('soccer', 3.6036615116182413),
#  ('sofrido', 3.6036615116182413),
#  ('solta', 3.6036615116182413),
#  ('soltar', 3.6036615116182413),
#  ('spoilers', 3.6036615116182413),
#  ('ssica', 3.6036615116182413),
#  ('substituição', 3.6036615116182413),
#  ('supermercado', 3.6036615116182413),
#  ('surto', 3.6036615116182413),
#  ('suspens', 3.6036615116182413),
#  ('sustentabilidade', 3.6036615116182413),
#  ('séries', 3.6036615116182413),
#  ('tabela,', 3.6036615116182413),
#  ('tava', 3.6036615116182413),
#  ('temporadas', 3.6036615116182413),
#  ('tensão', 3.6036615116182413),
#  ('tentam', 3.6036615116182413),
#  ('teoria', 3.6036615116182413),
#  ('teremos', 3.6036615116182413),
#  ('termo', 3.6036615116182413),
#  ('testar', 3.6036615116182413),
#  ('tiro', 3.6036615116182413),
#  ('tombam', 3.6036615116182413),
#  ('torcida.', 3.6036615116182413),
#  ('torcidas', 3.6036615116182413),
#  ('torneios', 3.6036615116182413),
#  ('trave', 3.6036615116182413),
#  ('treinadores', 3.6036615116182413),
#  ('treinamentos', 3.6036615116182413),
#  ('turistas', 3.6036615116182413),
#  ('término', 3.6036615116182413),
#  ('um,', 3.6036615116182413),
#  ('undefined', 3.6036615116182413),
#  ('unhas', 3.6036615116182413),
#  ('unificação', 3.6036615116182413),
#  ('universitária', 3.6036615116182413),
#  ('urgênciam', 3.6036615116182413),
#  ('utiliza', 3.6036615116182413),
#  ('utilizando', 3.6036615116182413),
#  ('utilizar', 3.6036615116182413),
#  ('van', 3.6036615116182413),
#  ('vasculham', 3.6036615116182413),
#  ('vem,', 3.6036615116182413),
#  ('venha', 3.6036615116182413),
#  ('vez.', 3.6036615116182413),
#  ('viabilidade,', 3.6036615116182413),
#  ('vice-presidente', 3.6036615116182413),
#  ('videoconferência', 3.6036615116182413),
#  ('vindo', 3.6036615116182413),
#  ('vingança', 3.6036615116182413),
#  ('vinha', 3.6036615116182413),
#  ('vinte', 3.6036615116182413),
#  ('violoncelista', 3.6036615116182413),
#  ('vira-lata', 3.6036615116182413),
#  ('visitantes', 3.6036615116182413),
#  ('visualizações', 3.6036615116182413),
#  ('viu?', 3.6036615116182413),
#  ('voluntário', 3.6036615116182413),
#  ('webcam', 3.6036615116182413),
#  ('y', 3.6036615116182413),
#  ('Áustria', 3.6036615116182413),
#  ('áfrica', 3.6036615116182413),
#  ('álcool', 3.6036615116182413),
#  ('área.', 3.6036615116182413),
#  ('época,', 3.6036615116182413),
#  ('ética', 3.6036615116182413),
#  ('íntegra', 3.6036615116182413),
#  ('ódio', 3.6036615116182413),
#  ('ótima', 3.6036615116182413),
#  ('ótimas', 3.6036615116182413),
#  ('‘epidemia’', 3.6036615116182413),
#  ('‘vendidos', 3.6036615116182413),
#  ('“É', 3.6036615116182413)]

# %% [markdown]
# ### Operacionalização para exclusão mútua entre Valorant e Counter Strike
# ### Counter Strike

# %% [markdown]
# #### Criando o RDD com documentos que possuem somente Counter Strike
# #### Filtrando o RDD

# %%
rdd_csgo_only = rdd_csgo.subtract(rdd_valorant_csgo)
rdd_csgo_only_doc_freq = rdd_csgo_only.flatMap(conta_palavras).reduceByKey(junta_contagens)
rdd_csgo_only_doc_freq_filtrado = rdd_csgo_only_doc_freq.filter(filtra_doc_freq)
rdd_csgo_only_doc_freq_filtrado.take(10)
# Out:
# [('26)', 1),
#  ('Quiz', 3),
#  ('intraparto?', 1),
#  ('Decision,', 1),
#  ('American', 8),
#  ('Pneumologia', 4),
#  ('favorito', 8),
#  ('25,00', 3),
#  ('R$30', 3),
#  ('avisado', 4)]

# %% [markdown]
# #### Calculando o IDF das palavras

# %%
rdd_csgo_only_idf = rdd_csgo_only_doc_freq_filtrado.map(idf)
result = rdd_csgo_only_idf.collect()
sorted(result, key=lambda x : x[1])[-100:]
# Out:
# [('(centro),', 4.557904021057566),
#  ('26.jul.2012', 4.557904021057566),
#  ('(PT-PE),', 4.557904021057566),
#  ('constelação', 4.557904021057566),
#  ('experimentou,', 4.557904021057566),
#  ('conseguisse', 4.557904021057566),
#  ('(Programação', 4.557904021057566),
#  ('Itapicuru,', 4.557904021057566),
#  ('Neurolingüística)PsicodramaPsicologia,', 4.557904021057566),
#  ('Febrap', 4.557904021057566),
#  ('Gestalt-terapia', 4.557904021057566),
#  ('frames.', 4.557904021057566),
#  ('Psicodramatista', 4.557904021057566),
#  ('vedação', 4.557904021057566),
#  ('Verani,', 4.557904021057566),
#  ('pensamento)', 4.557904021057566),
#  ('Elites', 4.557904021057566),
#  ('Trial', 4.557904021057566),
#  ('bug', 4.557904021057566),
#  ('LOL', 4.557904021057566),
#  ("12':", 4.557904021057566),
#  ('trailer:', 4.557904021057566),
#  ('escrúpulos', 4.557904021057566),
#  ('“Zeitschrift', 4.557904021057566),
#  ('Chopin', 4.557904021057566),
#  ('Octavius', 4.557904021057566),
#  ('Berthollet', 4.557904021057566),
#  ('Sigmund', 4.557904021057566),
#  ('Germanicus', 4.557904021057566),
#  ('amoníaco,', 4.557904021057566),
#  ('Lussac', 4.557904021057566),
#  ('Adolf', 4.557904021057566),
#  ('Emile', 4.557904021057566),
#  ('históricas.', 4.557904021057566),
#  ('brincalhão,', 4.557904021057566),
#  ('Plutão', 4.557904021057566),
#  ('incluem:', 4.557904021057566),
#  ('Zoomp', 4.557904021057566),
#  ('Zoop', 4.557904021057566),
#  ('MINIZINHA', 4.557904021057566),
#  ('AVISO:', 4.557904021057566),
#  ('podóloga', 4.557904021057566),
#  ('Sodexo', 4.557904021057566),
#  ('#366GotinhasdeGratidão', 4.557904021057566),
#  ('coloridas,', 4.557904021057566),
#  ('surpresa...', 4.557904021057566),
#  ('contador;', 4.557904021057566),
#  ('13:24', 4.557904021057566),
#  ('ubuntu', 4.557904021057566),
#  ('+Jogadores', 4.557904021057566),
#  ('Atualizado:', 4.557904021057566),
#  ('Petraglia', 4.557904021057566),
#  ('Viva!', 4.557904021057566),
#  ('pronunciamentos,', 4.557904021057566),
#  ('Pernambucanas', 4.557904021057566),
#  ('construia', 4.557904021057566),
#  ('Libertadora', 4.557904021057566),
#  ('Ciço,', 4.557904021057566),
#  ('arvore.', 4.557904021057566),
#  ('"Terra', 4.557904021057566),
#  ('pinga,', 4.557904021057566),
#  ('Nº:', 4.557904021057566),
#  ('Philomeno', 4.557904021057566),
#  ('classificasse', 4.557904021057566),
#  ('Possam', 4.557904021057566),
#  ('Nobre.', 4.557904021057566),
#  ('Oto', 4.557904021057566),
#  ('cativeiro,', 4.557904021057566),
#  ('cópias.', 4.557904021057566),
#  ('Carapinima', 4.557904021057566),
#  ('"Grafite"', 4.557904021057566),
#  ('Mororó', 4.557904021057566),
#  ('Letras.', 4.557904021057566),
#  ('Chefatura', 4.557904021057566),
#  ('Alagadiço', 4.557904021057566),
#  ('acção', 4.557904021057566),
#  ('Antigas', 4.557904021057566),
#  ('abolicionista.', 4.557904021057566),
#  ('Secult', 4.557904021057566),
#  ('geito.', 4.557904021057566),
#  ('concursados', 4.557904021057566),
#  ('(59%)', 4.557904021057566),
#  ("'luto',", 4.557904021057566),
#  ('Moreil,', 4.557904021057566),
#  ('chai', 4.557904021057566),
#  ('revelado', 4.557904021057566),
#  ('ODE', 4.557904021057566),
#  ('tentando,', 4.557904021057566),
#  ('"NÃO",', 4.557904021057566),
#  ('ARTICULISTAS', 4.557904021057566),
#  ('DESCONHECIDO', 4.557904021057566),
#  ('Espiritismo.', 4.557904021057566),
#  ('afastava', 4.557904021057566),
#  ('necessária,', 4.557904021057566),
#  ('aborto’', 4.557904021057566),
#  ('pró-liberdade', 4.557904021057566),
#  ('anteriormente.', 4.557904021057566),
#  ('desmagnetizador', 4.557904021057566),
#  ('d"Oeste', 4.557904021057566),
#  ('carbone', 4.557904021057566)]

# %% [markdown]
# #### Calculando a relevância das palavras

# %%
csgo_filtrado_sort_by_key_rdd = rdd_csgo_only_doc_freq_filtrado.sortByKey()
rdd_relevancia_csgo_only = csgo_filtrado_sort_by_key_rdd.map(relevancia)
res = rdd_relevancia_csgo_only.collect()
sorted(res, key=lambda x : x[1])[-100:]
# Out:
# [('problemas.', 3.6036615116182413),
#  ('procuram', 3.6036615116182413),
#  ('produtiva', 3.6036615116182413),
#  ('produtividade', 3.6036615116182413),
#  ('produtora', 3.6036615116182413),
#  ('profunda', 3.6036615116182413),
#  ('promocional', 3.6036615116182413),
#  ('provas', 3.6036615116182413),
#  ('pública,', 3.6036615116182413),
#  ('pública.', 3.6036615116182413),
#  ('públicas,', 3.6036615116182413),
#  ('públicos,', 3.6036615116182413),
#  ('que:', 3.6036615116182413),
#  ('razões', 3.6036615116182413),
#  ('recebi', 3.6036615116182413),
#  ('recebido', 3.6036615116182413),
#  ('recomendação', 3.6036615116182413),
#  ('referente', 3.6036615116182413),
#  ('regionais', 3.6036615116182413),
#  ('regularização', 3.6036615116182413),
#  ('relevantes', 3.6036615116182413),
#  ('relevância', 3.6036615116182413),
#  ('religião', 3.6036615116182413),
#  ('renovação', 3.6036615116182413),
#  ('repercussão', 3.6036615116182413),
#  ('residenciais', 3.6036615116182413),
#  ('residencial', 3.6036615116182413),
#  ('ressaltou', 3.6036615116182413),
#  ('revelando', 3.6036615116182413),
#  ('rurais', 3.6036615116182413),
#  ('saberes', 3.6036615116182413),
#  ('sala,', 3.6036615116182413),
#  ('salvo', 3.6036615116182413),
#  ('sao', 3.6036615116182413),
#  ('segmentos', 3.6036615116182413),
#  ('seminário', 3.6036615116182413),
#  ('sempre!', 3.6036615116182413),
#  ('sentidos', 3.6036615116182413),
#  ('seremos', 3.6036615116182413),
#  ('setembro,', 3.6036615116182413),
#  ('shopping', 3.6036615116182413),
#  ('silva', 3.6036615116182413),
#  ('simples,', 3.6036615116182413),
#  ('sinais', 3.6036615116182413),
#  ('situação,', 3.6036615116182413),
#  ('sobra', 3.6036615116182413),
#  ('solicite', 3.6036615116182413),
#  ('souza', 3.6036615116182413),
#  ('status', 3.6036615116182413),
#  ('sugere', 3.6036615116182413),
#  ('sugerir', 3.6036615116182413),
#  ('superfície', 3.6036615116182413),
#  ('superior,', 3.6036615116182413),
#  ('tambem', 3.6036615116182413),
#  ('tantas', 3.6036615116182413),
#  ('telefone,', 3.6036615116182413),
#  ('tendências', 3.6036615116182413),
#  ('teto', 3.6036615116182413),
#  ('teu', 3.6036615116182413),
#  ('tire', 3.6036615116182413),
#  ('tomada', 3.6036615116182413),
#  ('tornou-se', 3.6036615116182413),
#  ('total.', 3.6036615116182413),
#  ('trabalho:', 3.6036615116182413),
#  ('transição', 3.6036615116182413),
#  ('treinar', 3.6036615116182413),
#  ('tres', 3.6036615116182413),
#  ('trânsito,', 3.6036615116182413),
#  ('tu', 3.6036615116182413),
#  ('tudo.', 3.6036615116182413),
#  ('turistas', 3.6036615116182413),
#  ('união', 3.6036615116182413),
#  ('urbano', 3.6036615116182413),
#  ('vemos', 3.6036615116182413),
#  ('venceu', 3.6036615116182413),
#  ('vendedores', 3.6036615116182413),
#  ('vendendo', 3.6036615116182413),
#  ('vendido', 3.6036615116182413),
#  ('vigilância', 3.6036615116182413),
#  ('viram', 3.6036615116182413),
#  ('virtuais', 3.6036615116182413),
#  ('visibilidade', 3.6036615116182413),
#  ('viúva', 3.6036615116182413),
#  ('voce', 3.6036615116182413),
#  ('voltados', 3.6036615116182413),
#  ('volte', 3.6036615116182413),
#  ('voo', 3.6036615116182413),
#  ('vêm', 3.6036615116182413),
#  ('vírus', 3.6036615116182413),
#  ('ÉTICA', 3.6036615116182413),
#  ('Índio', 3.6036615116182413),
#  ('Óculos', 3.6036615116182413),
#  ('Úteis', 3.6036615116182413),
#  ('ás', 3.6036615116182413),
#  ('é.', 3.6036615116182413),
#  ('ênfase', 3.6036615116182413),
#  ('óbitos', 3.6036615116182413),
#  ('“', 3.6036615116182413),
#  ('“Se', 3.6036615116182413),
#  ('”', 3.6036615116182413)]

# %% [markdown]
# ### Valorant

# %% [markdown]
# #### Criando o RDD com documentos que possuem somente Counter Strike
# #### Filtrando o RDD

# %%
rdd_valorant_only = rdd_valorant.subtract(rdd_valorant_csgo)
rdd_valorant_only_doc_freq = rdd_valorant_only.flatMap(conta_palavras).reduceByKey(junta_contagens)
rdd_valorant_only_doc_freq_filtrado = rdd_valorant_only_doc_freq.filter(filtra_doc_freq)
rdd_valorant_only_doc_freq_filtrado.take(10)
# Out:
# [('Sobrado', 5),
#  ('Mariluz', 1),
#  ('garopaba', 2),
#  ('Atlântida,', 1),
#  ('12:05', 7),
#  ('litoral', 3),
#  ('Varanda/Terraço', 4),
#  ('04:34', 1),
#  ('namoro', 7),
#  ('Companhia', 8)]

# %% [markdown]
# #### Calculando o IDF das palavras

# %%
rdd_valorant_only_idf = rdd_valorant_only_doc_freq_filtrado.map(idf)
result = rdd_valorant_only_idf.collect()
sorted(result, key=lambda x : x[1])[-100:]
# Out:
# [('furto,', 4.557904021057566),
#  ('Ontem23:39', 4.557904021057566),
#  ('2.390', 4.557904021057566),
#  ('1.300R$', 4.557904021057566),
#  ('cod:01353.314', 4.557904021057566),
#  ('Pelicanos', 4.557904021057566),
#  ('3.850.000', 4.557904021057566),
#  ('CT-Agronegócio', 4.557904021057566),
#  ('FUNTTEL', 4.557904021057566),
#  ('Geoestacionário', 4.557904021057566),
#  ('montada', 4.557904021057566),
#  ('MUNICÍPIO,', 4.557904021057566),
#  ('royalties', 4.557904021057566),
#  ('1º...', 4.557904021057566),
#  ('Informativos', 4.557904021057566),
#  ('Zero,', 4.557904021057566),
#  ('gay.', 4.557904021057566),
#  ('12,000.00', 4.557904021057566),
#  ('Apocalipse', 4.557904021057566),
#  ('estarrecer', 4.557904021057566),
#  ('UFF', 4.557904021057566),
#  ('Tautou', 4.557904021057566),
#  ('3106-9995', 4.557904021057566),
#  ('2596-7599', 4.557904021057566),
#  ('Shimon', 4.557904021057566),
#  ('estrelados', 4.557904021057566),
#  ('Estudos,', 4.557904021057566),
#  ("'fora,", 4.557904021057566),
#  ('Cabanga', 4.557904021057566),
#  ('Perí', 4.557904021057566),
#  ('Timbu.', 4.557904021057566),
#  ('acessaram', 4.557904021057566),
#  ('807', 4.557904021057566),
#  ('Corinthians;', 4.557904021057566),
#  ('19ARO', 4.557904021057566),
#  ('Summer', 4.557904021057566),
#  ('Doll', 4.557904021057566),
#  ('Mecanismos', 4.557904021057566),
#  ('BerçosBerços', 4.557904021057566),
#  ('Limpeza!!', 4.557904021057566),
#  ('preparados,', 4.557904021057566),
#  ('Aparecido', 4.557904021057566),
#  ('Magrão.', 4.557904021057566),
#  ('Elano,', 4.557904021057566),
#  ('escultura', 4.557904021057566),
#  ('5…', 4.557904021057566),
#  ('10,262SeguidoresSeguir', 4.557904021057566),
#  ('resolve.', 4.557904021057566),
#  ('lideranças.', 4.557904021057566),
#  ('anteriorCom', 4.557904021057566),
#  ('mescla', 4.557904021057566),
#  ('carinho,', 4.557904021057566),
#  ('Lobo”,', 4.557904021057566),
#  ('reciclada', 4.557904021057566),
#  ('22:13', 4.557904021057566),
#  ('Diamond', 4.557904021057566),
#  ('Otero,', 4.557904021057566),
#  ('experiencia', 4.557904021057566),
#  ('ois', 4.557904021057566),
#  ('despedida,', 4.557904021057566),
#  ('“tirou', 4.557904021057566),
#  ('incompetente,', 4.557904021057566),
#  ('31/12/2018,', 4.557904021057566),
#  ('orientando', 4.557904021057566),
#  ('correspondeu', 4.557904021057566),
#  ('custará', 4.557904021057566),
#  ('cruzamentos.', 4.557904021057566),
#  ('assinasse', 4.557904021057566),
#  ('interagindo', 4.557904021057566),
#  ('circuit', 4.557904021057566),
#  ('slick,', 4.557904021057566),
#  ('maiores.', 4.557904021057566),
#  ('Tétrico', 4.557904021057566),
#  ('1.035', 4.557904021057566),
#  ('melbourne', 4.557904021057566),
#  ('heidfeld', 4.557904021057566),
#  ('bandeiraverde.com.br/2017/02/17/por…', 4.557904021057566),
#  ('Lamy,', 4.557904021057566),
#  ('BARTHEZ,', 4.557904021057566),
#  ('prix,', 4.557904021057566),
#  ('barthez,', 4.557904021057566),
#  ('shanghai', 4.557904021057566),
#  ('Henry!', 4.557904021057566),
#  ('bautizó', 4.557904021057566),
#  ('hospedada.', 4.557904021057566),
#  ('Tevez,', 4.557904021057566),
#  ('1542,60m²', 4.557904021057566),
#  ('Ontem17:40', 4.557904021057566),
#  ('M²', 4.557904021057566),
#  ('seleções),', 4.557904021057566),
#  ('“Deus', 4.557904021057566),
#  ('MID', 4.557904021057566),
#  ('Júniors', 4.557904021057566),
#  ('pelaseliminatórias.', 4.557904021057566),
#  ('Ontem20:16', 4.557904021057566),
#  ('decorativa', 4.557904021057566),
#  ('Eletrodomésticos(263)', 4.557904021057566),
#  ('Instalada!!', 4.557904021057566),
#  ('Piscinas!', 4.557904021057566),
#  ('Hoje11:03', 4.557904021057566)]

# %% [markdown]
# #### Calculando a relevância das palavras

# %%
valorant_filtrado_sort_by_key_rdd = rdd_valorant_only_doc_freq_filtrado.sortByKey()
rdd_relevancia_valorant_only = valorant_filtrado_sort_by_key_rdd.map(relevancia)
res = rdd_relevancia_valorant_only.collect()
sorted(res, key=lambda x : x[1])[-100:]
# Out:
# [('pedras', 3.6036615116182413),
#  ('pessoas,', 3.6036615116182413),
#  ('peça', 3.6036615116182413),
#  ('pilota', 3.6036615116182413),
#  ('pilotam', 3.6036615116182413),
#  ('piso', 3.6036615116182413),
#  ('positivos', 3.6036615116182413),
#  ('postagem', 3.6036615116182413),
#  ('postos', 3.6036615116182413),
#  ('praticar', 3.6036615116182413),
#  ('praça', 3.6036615116182413),
#  ('precisou', 3.6036615116182413),
#  ('preocupação', 3.6036615116182413),
#  ('preservar', 3.6036615116182413),
#  ('preto', 3.6036615116182413),
#  ('privado', 3.6036615116182413),
#  ('procedimentos', 3.6036615116182413),
#  ('profissional,', 3.6036615116182413),
#  ('proíbe', 3.6036615116182413),
#  ('páginas', 3.6036615116182413),
#  ('pênalti', 3.6036615116182413),
#  ('pênaltis', 3.6036615116182413),
#  ('pública,', 3.6036615116182413),
#  ('quarta,', 3.6036615116182413),
#  ('que...', 3.6036615116182413),
#  ('quilômetros', 3.6036615116182413),
#  ('rabino', 3.6036615116182413),
#  ('rapaz', 3.6036615116182413),
#  ('reality', 3.6036615116182413),
#  ('rebaixamento', 3.6036615116182413),
#  ('reciclados', 3.6036615116182413),
#  ('recuperar', 3.6036615116182413),
#  ('refere', 3.6036615116182413),
#  ('regência', 3.6036615116182413),
#  ('rei', 3.6036615116182413),
#  ('renova', 3.6036615116182413),
#  ('residência', 3.6036615116182413),
#  ('respondeu', 3.6036615116182413),
#  ('restrição:', 3.6036615116182413),
#  ('reverter', 3.6036615116182413),
#  ('rom', 3.6036615116182413),
#  ('runners', 3.6036615116182413),
#  ('salvar', 3.6036615116182413),
#  ('salários', 3.6036615116182413),
#  ('sambar"', 3.6036615116182413),
#  ('sangue', 3.6036615116182413),
#  ('seguintes', 3.6036615116182413),
#  ('segura', 3.6036615116182413),
#  ('seguro', 3.6036615116182413),
#  ('semestre', 3.6036615116182413),
#  ('sensação', 3.6036615116182413),
#  ('serve', 3.6036615116182413),
#  ('servir', 3.6036615116182413),
#  ('setembro.', 3.6036615116182413),
#  ('setores', 3.6036615116182413),
#  ('showroom', 3.6036615116182413),
#  ('sinais', 3.6036615116182413),
#  ('sintomas', 3.6036615116182413),
#  ('skate', 3.6036615116182413),
#  ('sorte', 3.6036615116182413),
#  ('sorteia', 3.6036615116182413),
#  ('sozinho', 3.6036615116182413),
#  ('suficiente', 3.6036615116182413),
#  ('talk', 3.6036615116182413),
#  ('tantos', 3.6036615116182413),
#  ('telefonia', 3.6036615116182413),
#  ('temas', 3.6036615116182413),
#  ('tentam', 3.6036615116182413),
#  ('termina', 3.6036615116182413),
#  ('terreno', 3.6036615116182413),
#  ('textos', 3.6036615116182413),
#  ('time.', 3.6036615116182413),
#  ('tipos', 3.6036615116182413),
#  ('tiro', 3.6036615116182413),
#  ('torsion', 3.6036615116182413),
#  ('treinamento', 3.6036615116182413),
#  ('tudo,', 3.6036615116182413),
#  ('tudo.', 3.6036615116182413),
#  ('turma', 3.6036615116182413),
#  ('utilização', 3.6036615116182413),
#  ('venda,', 3.6036615116182413),
#  ('vendidos', 3.6036615116182413),
#  ('ver,', 3.6036615116182413),
#  ('verdade,', 3.6036615116182413),
#  ('versões', 3.6036615116182413),
#  ('vida,', 3.6036615116182413),
#  ('vidro', 3.6036615116182413),
#  ('vinha', 3.6036615116182413),
#  ('visitantes', 3.6036615116182413),
#  ('visão', 3.6036615116182413),
#  ('von', 3.6036615116182413),
#  ('webinar', 3.6036615116182413),
#  ('Às', 3.6036615116182413),
#  ('Éticos"', 3.6036615116182413),
#  ('Ônibus', 3.6036615116182413),
#  ('Única', 3.6036615116182413),
#  ('águas', 3.6036615116182413),
#  ('árvores', 3.6036615116182413),
#  ('úteis', 3.6036615116182413),
#  ('‘Horizontes:', 3.6036615116182413)]

# %%
sc.stop()
